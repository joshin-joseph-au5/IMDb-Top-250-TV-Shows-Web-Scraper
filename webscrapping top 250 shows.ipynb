# %% [markdown]
#                                    ###web scrapping ### top 250 tv shows

# %% [markdown]
# Web Scrapping
# • Web scraping is the process of extracting information from websites.
# • Two popular tools for this task are Selenium and BeautifulSoup.
# • Each has its strengths and is often used together to leverage their combined capabilities.
#
# BeautifulSoup
# • BeautifulSoup is a library for parsing HTML and XML documents.
# • It helps to navigate the HTML structure, search for elements, and extract data.
# • It is particularly effective for handling and cleaning up the HTML after fetching it, making it easier to extract the desired information.
#
# Selenium
# • Selenium is a powerful tool for automating web browsers.
# • It can simulate user interactions, such as clicking buttons, filling out forms, and scrolling through pages.
# • This makes it especially useful for scraping dynamic content that is loaded via JavaScript or requires user actions.

# %% [markdown]
# Libraries Used
#
# pandas
# • This library is used for data manipulation and analysis.
# • It provides powerful data structures like DataFrames which are great for organizing and analyzing data scraped from websites.
# • For example, after scraping data you can use pandas to clean and save the data in various formats like CSV or Excel.
#
# requests
# • This library allows you to send HTTP requests using Python.
# • It's often used to fetch the HTML content of a webpage.
# • With requests, you can easily retrieve the page source which can then be parsed to extract the desired information.
#
# BeautifulSoup
# • This library is used for parsing HTML and XML documents.
# • It makes it easy to navigate and search the HTML structure of a webpage.
# • After retrieving the HTML content using requests you can use BeautifulSoup to parse and extract specific elements of the webpage.
#
# selenium
# • This library is used for automating web browsers.
# • It allows you to interact with web pages, which is particularly useful for scraping dynamic content that is loaded via JavaScript.
# • Selenium can simulate user interactions such as clicking buttons, filling out forms and scrolling.
#
# webdriver_manager
# • This library is used to automatically manage browser drivers for Selenium.
# • Instead of manually downloading and setting up browser drivers, webdriver_manager handles the installation and setup for you.
# • This simplifies the process of ensuring you have the correct driver version for your browser.

# %%
import pandas as pd
# requests
import requests
# BeautifulSoup
from bs4 import BeautifulSoup
# selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Setting Up Selenium WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Navigating to a Web Page
driver.get("https://www.imdb.com/chart/toptv/")

# Scrolling to the Bottom of the Page
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# Adding a Time Gap for Loading Content
import time
time.sleep(10)

# Saving the Final HTML and Closing the Browser
html = driver.page_source
driver.quit()

# %%
# Creating BeautifulSoup Object
soup = BeautifulSoup(html, "lxml")

# %%
# Heading of the Webpage
heading = soup.find("h1").text
print(heading)
# Out:
# Top 250 TV Shows

# %%
# TV Shows Name
lst1 = []
for i in soup.find_all("h3","ipc-title__text"):
    lst1.append(i.text)

print(lst1)
# Out:
# ['IMDb Charts', '1. Breaking Bad', '2. Planet Earth II', '3. Planet Earth', '4. Band of Brothers', '5. Chernobyl', '6. The Wire', '7. Avatar: The Last Airbender', '8. Blue Planet II', '9. The Sopranos', '10. Cosmos: A Spacetime Odyssey', '11. Cosmos', '12. Our Planet', '13. Game of Thrones', '14. Bluey', '15. The World at War', '16. Fullmetal Alchemist: Brotherhood', '17. Rick and Morty', '18. Life', '19. The Last Dance', '20. The Twilight Zone', '21. The Vietnam War', '22. Sherlock', '23. Attack on Titan', '24. Batman: The Animated Series', '25.
Boys', '112. Justice League Unlimited', '113. Monster', '114. Invincible', '115. The Adventures of Sherlock Holmes', '116. Mahabharat', '117. Friday Night Lights', '118. Stranger Things', '119. The Marvelous Mrs. Maisel', '120. Line of Duty', '121. Top Gear', '122. 1883', '123. The Thick of It', '124. How to with John Wilson', '125. Behzat Ç: An Ankara Detective Story', '126. The Penguin', '127. This Is Us', '128. Sarabhai V/S Sarabhai', '129. Father Ted', '130. Aspirants', '131. The Mandalorian', '132. Code Geass', '133. House of Cards', '134. Parks and Recreation', '135. Atlanta', '136. The X-Files', '137. Deadwood', '138. Dexter', '139. Adventure Time', '140. The Crown', '141. Ramayan', "142. It's a Sin", '143. Shōgun', '144. The Bridge', '145. Primal', '146. Daredevil', '147. Lonesome Dove', '148. Blackadder II', '149. Mr Inbetween', '150. Mindhunter', '151. Poirot', '152. Haikyu!!', '153. Mr. Bean', '154. The Jinx: The Life and Deaths of Robert Durst', '155. The Return of Sherlock Holmes', '156. The Offer', '157. Crash Landing on You', '158. Gomorrah', '159. Fighting Spirit', '160. Scavengers Reign', '161. Yes Minister', '162. Pose', '163. Blackadder the Third', '164. Mystery Science Theater 3000', '165. Anne with an E', '166. Greatest Events of WWII in Colour', '167. Archer', '168. The Newsroom', '169. Dopesick', '170. Critical Role', '171. Demon Slayer: Kimetsu no Yaiba', '172. Yeh Meri Family', '173. Boardwalk Empire', '174. The Bureau', '175. Young Justice', '176. El Chavo del Ocho', '177. Homicide: Life on the Street', '178. QI', '179. Justified', '180. The Bugs ...

# %%
# Name of TV Show
name_list = []
for i in lst1:
    name_list.append(i.split(".")[1].strip())

print(name_list)
# Out:
# ['Breaking Bad', 'Planet Earth II', 'Planet Earth', 'Band of Brothers', 'Chernobyl', 'The Wire', 'Avatar: The Last Airbender', 'Blue Planet II', 'The Sopranos', 'Cosmos: A Spacetime Odyssey', 'Cosmos', 'Our Planet', 'Game of Thrones', 'Bluey', 'The World at War', 'Fullmetal Alchemist: Brotherhood', 'Rick and Morty', 'Life', 'The Last Dance', 'The Twilight Zone', 'The Vietnam War', 'Sherlock', 'Attack on Titan', 'Batman: The Animated Series', 'Arcane', 'Better Call Saul', 'The Office', 'The Blue Planet', "Clarkson's Farm", 'Scam 1992: The Harshad Mehta Story', 'Human Planet', 'Frozen Planet', 'Hunter x Hunter', 'Firefly', 'Only Fools and Horses', 'The Civil War', 'Death Note', 'Gravity Falls', 'Seinfeld', 'Dekalog', 'The Beatles: Get Back', 'Cowboy Bebop', 'True Detective', 'Fargo', 'As If', 'Nathan for You', 'Persona', 'Apocalypse: The Second World War', 'Taskmaster', 'Africa', 'When They See Us', 'Friends', "Frieren: Beyond Journey's End", 'Last Week Tonight with John Oliver', "It's Always Sunny in Philadelphia", 'Succession', 'TVF Pitchers', 'The West Wing', 'One Piece', "Monty Python's Flying Circus", 'Curb Your Enthusiasm', 'Das Boot', 'BoJack Horseman', 'The Chosen', 'Fawlty Towers', 'Leyla and Mecnun', 'Dragon Ball Z', 'Blackadder Goes Forth', 'Panchayat', 'Pride and Prejudice', 'Freaks and Geeks', 'Twin Peaks', 'Dragon Ball Z', "Chappelle's Show", 'Narcos', 'Bleach: Thousand-Year Blood War', 'Vinland Saga', 'Gullak', 'I, Claudius', 'Kota Factory', 'South Park', 'Black Mirror', 'Over the Garden Wall', 'Ted Lasso', "X-Men '97", 'Reply 1988', 'Peaky Blinders', 'Six Feet Under', 'Steins;Gate', 'Rome', 'Oz', 'My Mister', 'Dark', 'Berserk', 'Fleabag', 'The Last of Us', 'Downton Abbey', 'The Shield', 'Battlestar Galactica', 'Severance', 'The Grand Tour', 'Blue Eye Samurai', 'The Simpsons', 'Mad Men', 'Peep Show', 'Star Trek: The Next Generation', 'House', 'Arrested Development', 'One Punch Man', 'Naruto: Shippuden', 'The Boys', 'Justice League Unlimited', 'Monster', 'Invincible', 'The Adventures of Sherlock Holmes', 'Mahabharat', 'Friday Night Lights', 'Stranger Things', 'The Marvelous Mrs', 'Line of Duty', 'Top Gear', '1883', 'The Thick of It', 'How to with John Wilson', 'Behzat Ç: An Ankara Detective Story', 'The Penguin', 'This Is Us', 'Sarabhai V/S Sarabhai', 'Father Ted', 'Aspirants', 'The Mandalorian', 'Code Geass', 'House of Cards', 'Parks and Recreation', 'Atlanta', 'The X-Files', 'Deadwood', 'Dexter', 'Adventure Time', 'The Crown', 'Ramayan', "It's a Sin", 'Shōgun', 'The Bridge', 'Primal', 'Daredevil', 'Lonesome Dove', 'Blackadder II', 'Mr Inbetween', 'Mindhunter', 'Poirot', 'Haikyu!!', 'Mr', 'The Jinx: The Life and Deaths of Robert Durst', 'The Return of Sherlock Holmes', 'The Offer', 'Crash Landing on You', 'Gomorrah', 'Fighting Spirit', 'Scavengers Reign', 'Yes Minister', 'Pose', 'Blackadder the Third', 'Mystery Science Theater 3000', 'Anne with an E', 'Greatest Events of WWII in Colour', 'Archer', 'The Newsroom', 'Dopesick', 'Critical Role', 'Demon Slayer: Kimetsu no Yaiba', 'Yeh Meri Family', 'Boardwalk Empire', 'The Bureau', 'Young Justice', 'El Chavo del Ocho', 'Homicide: Life on the Street', 'QI', 'Justified', 'The Bugs Bunny Show', 'What We Do in the Shadows', 'The Family Man', 'The Haunting of Hill House', 'Dragon Ball', 'Justice League', 'Battlestar Galactica', 'The Venture Bros', 'Dragon Ball', 'Endeavour', 'Yes, Prime Minister', 'Yellowstone', 'Flight of the Conchords', 'The Bear', 'Samurai Champloo', "The Queen's Gambit", 'Rocket Boys', 'Coupling', 'The IT Crowd', 'Making a Murderer', 'Ezel', 'Mr', 'Black Sun', "I'm Alan Partridge", 'Impractical Jokers', 'Samurai Jack', 'Jujutsu Kaisen', 'Detectorists', 'Happy Valley', 'Spaced', 'Long Way Round', 'Mob Psycho 100', 'Spartacus', 'The Eric Andre Show', 'Whose Line Is It Anyway?', 'Regular Show', 'Louie', 'Sons of Anarchy', 'Derry Girls', 'Through the Wormhole', 'The Office', 'Twin Peaks', 'Neon Genesis Evangelion', 'Trailer Park Boys', 'Formula 1: Drive to  ...

# %%
# IMDB Rating
rating = []
for i in soup.find_all("span","ipc-rating-star--rating"):
    rating.append(i.text.strip())

print(rating)
# Out:
# ['9.5', '9.5', '9.4', '9.4', '9.3', '9.3', '9.3', '9.3', '9.2', '9.2', '9.3', '9.2', '9.2', '9.3', '9.2', '9.1', '9.1', '9.1', '9.0', '9.0', '9.1', '9.1', '9.1', '9.0', '9.0', '9.0', '9.0', '9.0', '9.0', '9.2', '9.0', '9.0', '9.0', '8.9', '9.0', '9.0', '8.9', '8.9', '8.9', '8.9', '8.9', '8.9', '8.9', '8.9', '9.0', '8.9', '9.0', '9.0', '9.0', '8.9', '8.8', '8.9', '8.9', '8.8', '8.8', '8.8', '9.1', '8.9', '9.0', '8.8', '8.8', '8.8', '8.8', '9.1', '8.8', '9.1', '8.8', '8.8', '9.0', '8.8', '8.8', '8.7', '8.8', '8.8', '8.7', '9.0', '8.8', '9.1', '8.8', '9.0', '8.7', '8.7', '8.7', '8.8', '8.8', '9.0', '8.7', '8.7', '8.8', '8.7', '8.7', '9.0', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.6', '8.7', '8.9', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.7', '8.8', '8.6', '8.7', '8.9', '8.7', '9.2', '8.6', '8.7', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '9.0', '8.6', '8.6', '8.6', '8.7', '8.6', '8.7', '8.6', '8.7', '8.6', '8.6', '8.7', '8.6', '8.6', '8.7', '8.6', '8.7', '8.6', '8.8', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '8.6', '9.0', '8.6', '8.9', '8.6', '8.7', '8.6', '8.7', '8.7', '8.6', '8.6', '8.6', '8.6', '8.7', '8.5', '8.5', '8.5', '8.5', '8.6', '8.5', '8.6', '8.6', '8.6', '8.5', '8.5', '8.5', '8.5', '8.9', '8.5', '8.5', '8.5', '8.6', '8.5', '8.8', '8.6', '8.6', '8.5', '8.5', '8.6', '8.5', '8.5', '8.6', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.6', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.5', '8.6', '8.5', '8.6', '8.5', '8.6', '8.6', '8.7', '8.5', '8.6', '8.5', '8.5', '8.5', '8.5', '8.6', '8.6', '8.6', '8.6', '8.6', '8.7', '8.7', '8.6', '8.5', '9.0', '8.6']

# %%
# Votes for TV Shows
lst2 = []
for i in soup.find_all("span","ipc-rating-star--voteCount"):
# %%
# Audience Votes
votes = []
for i in lst2:
    votes.append(i.replace("(","").replace(")","").strip())

print(votes)
# Out:
# ['2.3M', '164K', '226K', '551K', '921K', '395K', '395K', '51K', '507K', '133K', '47K', '55K', '2.4M', '36K', '33K', '213K', '634K', '45K', '162K', '99K', '31K', '1M', '577K', '124K', '367K', '703K', '756K', '45K', '69K', '163K', '30K', '35K', '154K', '288K', '60K', '21K', '408K', '150K', '364K', '30K', '31K', '149K', '685K', '438K', '27K', '42K', '51K', '16K', '24K', '19K', '145K', '1.1M', '32K', '99K', '262K', '303K', '75K', '90K', '278K', '82K', '155K', '36K', '204K', '54K', '104K', '99K', '158K', '60K', '101K', '97K', '158K', '224K', '94K', '75K', '491K', '56K', '90K', '26K', '21K', '87K', '417K', '667K', '78K', '382K', '40K', '15K', '692K', '156K', '80K', '192K', '111K', '12K', '475K', '62K', '219K', '595K', '232K', '92K', '180K', '240K', '89K', '85K', '448K', '270K', '69K', '142K', '544K', '332K', '196K', '188K', '749K', '22K', '53K', '226K', '26K', '25K', '75K', '1.4M', '149K', '74K', '131K', '129K', '28K', '15K', '34K', '161K', '165K', '19K', '46K', '315K', '612K', '87K', '542K', '298K', '93K', '258K', '122K', '816K', '120K', '266K', '25K', '39K', '198K', '80K', '24K', '489K', '28K', '52K', '37K', '358K', '55K', '42K', '140K', '55K', '14K', '44K', '48K', '47K', '13K', '27K', '18K', '35K', '49K', '27K', '72K', '12K', '170K', '129K', '84K', '14K', '176K', '27K', '209K', '16K', '48K', '14K', '16K', '35K', '123K', '37K', '115K', '103K', '304K', '70K', '54K', '82K', '29K', '68K', '35K', '14K', '254K', '68K', '259K', '58K', '596K', '19K', '49K', '169K', '105K', '40K', '434K', '13K', '23K', '48K', '62K', '141K', '23K', '68K', '59K', '16K', '52K', '264K', '23K', '48K', '64K', '84K', '335K', '66K', '19K', '127K', '80K', '93K', '53K', '54K', '156K', '149K', '12K', '303K', '40K', '172K', '21K', '17K', '21K', '268K', '36K', '81K', '180K', '287K', '254K', '31K', '22K', '14K', '26K', '19K', '17K', '12K', '32K', '42K', '13K', '19K']

# %%
# Collecting all the Data into a DataFrame
tv_shows = pd.DataFrame({"Name":name_list,"Ratings":rating,"Votes":votes})
tv_shows.head(10)
# Out:
#                           Name Ratings Votes
# 0                 Breaking Bad     9.5  2.3M
# 1              Planet Earth II     9.5  164K
# 2                 Planet Earth     9.4  226K
# 3             Band of Brothers     9.4  551K
# 4                    Chernobyl     9.3  921K
# 5                     The Wire     9.3  395K
# 6   Avatar: The Last Airbender     9.3  395K
# 7               Blue Planet II     9.3   51K
# 8                 The Sopranos     9.2  507K
# 9  Cosmos: A Spacetime Odyssey     9.2  133K

# %%
# Saving the DataFrame as CSV File
tv_shows.to_csv("tv_shows.csv",index=False)
